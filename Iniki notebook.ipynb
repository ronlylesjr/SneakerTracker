# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("sneaker_sales\Adidas Iniki Runner Core Black.csv")
df.head()
# Out:
#    Unnamed: 0            createdAt  amount  shoeSize
# 0           0  2017-08-12 01:04:16     145      12.0
# 1           1  2017-08-11 16:00:14     150       8.0
# 2           2  2017-08-11 15:18:07     150       8.5
# 3           3  2017-08-11 08:01:23     150      11.0
# 4           4  2017-08-11 01:16:22     120       8.5

# %%
df['createdAt'] = df['createdAt'].astype('datetime64[ns]')
df.head()
# Out:
#    Unnamed: 0           createdAt  amount  shoeSize
# 0           0 2017-08-12 01:04:16     145      12.0
# 1           1 2017-08-11 16:00:14     150       8.0
# 2           2 2017-08-11 15:18:07     150       8.5
# 3           3 2017-08-11 08:01:23     150      11.0
# 4           4 2017-08-11 01:16:22     120       8.5

# %%
# df.sort_values(by='Unnamed: 0', ascending=False)
df.sort_values(by='createdAt', ascending=True)
df['obs'] = [x for x in range(0, len(df))]
df.head()
# Out:
#    Unnamed: 0           createdAt  amount  shoeSize  obs
# 0           0 2017-08-12 01:04:16     145      12.0    0
# 1           1 2017-08-11 16:00:14     150       8.0    1
# 2           2 2017-08-11 15:18:07     150       8.5    2
# 3           3 2017-08-11 08:01:23     150      11.0    3
# 4           4 2017-08-11 01:16:22     120       8.5    4

# %%
df2 = df[['createdAt', 'amount']]
# plt.rcParams['figure.figsize']=(20,10)
lm = sns.lmplot(data=df, x='obs', y='amount', col='shoeSize', col_wrap=3)
axes = lm.axes
axes[0,].set_ylim(60,225)

# plt.plot(df['createdAt'], df['amount'])
# plt.figure(figsize=(5,9), dpi=100)
# plt.show()
# Out:
# (60, 225)

# %%
sns.distplot(df['shoeSize'])
# Out:
# C:\Users\ok\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
sns.boxplot(data=df, x='shoeSize', y='amount')
